# %%
import pandas as pd

data=pd.read_csv('Gesture.csv')

# %%
data.head()
# Out:
#           0         1             2         3         4         5         6  \
# 0  0.349521  0.946235  1.041323e-08  0.400292  0.897789 -0.017082  0.437248
# 1  0.356054  0.889126  3.322881e-09  0.409556  0.818951 -0.008967  0.445764
# 2  0.367713  0.836388  5.937537e-09  0.420963  0.765773  0.000296  0.454989
# 3  0.374717  0.803757  4.914791e-09  0.429269  0.739156 -0.002441  0.464815
# 4  0.394697  0.786096  1.169030e-08  0.442328  0.710840  0.002682  0.473604
#
#           7         8         9  ...        54        55        56        57  \
# 0  0.805162 -0.036421  0.443693  ...  0.314514  0.764170 -0.076151  0.330852
# 1  0.706364 -0.024479  0.448791  ...  0.332939  0.646613 -0.070065  0.349364
# 2  0.642715 -0.012918  0.460822  ...  0.363202  0.575319 -0.072003  0.373451
# 3  0.610430 -0.013463  0.472985  ...  0.380317  0.519313 -0.064993  0.390776
# 4  0.581411 -0.009070  0.480804  ...  0.394037  0.505348 -0.062782  0.404706
#
#          58        59        60        61        62    Gesture
# 0  0.812204 -0.072323  0.331377  0.844207 -0.069907   Gesture1
# 1  0.701909 -0.063252  0.343719  0.739569 -0.055285   Gesture1
# 2  0.643924 -0.064360  0.359523  0.687392 -0.055860   Gesture1
# 3  0.586487 -0.056303  0.376907  0.628729 -0.045911   Gesture1
# 4  0.571282 -0.053366  0.386051  0.607669 -0.043476   Gesture1
#
# [5 rows x 64 columns]

# %%
data
# Out:
#              0         1             2         3         4         5  \
# 0     0.349521  0.946235  1.041323e-08  0.400292  0.897789 -0.017082
# 1     0.356054  0.889126  3.322881e-09  0.409556  0.818951 -0.008967
# 2     0.367713  0.836388  5.937537e-09  0.420963  0.765773  0.000296
# 3     0.374717  0.803757  4.914791e-09  0.429269  0.739156 -0.002441
# 4     0.394697  0.786096  1.169030e-08  0.442328  0.710840  0.002682
# ...        ...       ...           ...       ...       ...       ...
# 1576  0.319922  0.873857  1.210906e-08  0.386351  0.820267 -0.020293
# 1577  0.320479  0.873035  1.184288e-08  0.386728  0.821369 -0.020134
# 1578  0.319432  0.882993  1.228419e-08  0.383232  0.834416 -0.022517
# 1579  0.315863  0.927647  1.315793e-08  0.378345  0.882899 -0.018088
# 1580  0.315905  0.970411  1.206323e-08  0.375980  0.955115 -0.044923
#
#              6         7         8         9  ...        54        55  \
# 0     0.437248  0.805162 -0.036421  0.443693  ...  0.314514  0.764170
# 1     0.445764  0.706364 -0.024479  0.448791  ...  0.332939  0.646613
# 2     0.454989  0.642715 -0.012918  0.460822  ...  0.363202  0.575319
# 3     0.464815  0.610430 -0.013463  0.472985  ...  0.380317  0.519313
# 4     0.473604  0.581411 -0.009070  0.480804  ...  0.394037  0.505348
# ...        ...       ...       ...       ...  ...       ...       ...
# 1576  0.427888  0.702369 -0.024389  0.388677  ...  0.286477  0.438017
# 1577  0.429083  0.705771 -0.024786  0.391591  ...  0.287987  0.439297
# 1578  0.426253  0.719787 -0.028296  0.392344  ...  0.288847  0.448840
# 1579  0.424904  0.768099 -0.023070  0.396275  ...  0.289042  0.480437
# 1580  0.425282  0.912162 -0.077297  0.439808  ...  0.295309  0.549313
#
#             56        57        58        59        60        61        62  \
# 0    -0.076151  0.330852  0.812204 -0.072323  0.331377  0.844207 -0.069907
# 1    -0.070065  0.349364  0.701909 -0.063252  0.343719  0.739569 -0.055285
# 2    -0.072003  0.373451  0.643924 -0.064360  0.359523  0.687392 -0.055860
# 3    -0.064993  0.390776  0.586487 -0.056303  0.376907  0.628729 -0.045911
# 4    -0.062782  0.404706  0.571282 -0.053366  0.386051  0.607669 -0.043476
# ...        ...       ...       ...       ...       ...       ...       ...
# 1576 -0.022148  0.268795  0.368112 -0.032706  0.254219  0.302626 -0.041621
# 1577 -0.023177  0.270653  0.368842 -0.033535  0.256096  0.303351 -0.042367
# 1578 -0.028464  0.271359  0.377744 -0.040342  0.255806  0.312043 -0.050275
# 1579 -0.038785  0.272177  0.402238 -0.051390  0.256303  0.331279 -0.062245
# 1580 -0.099679  0.281936  0.467913 -0.116100  0.272866  0.396386 -0.130187
#
#         Gesture
# 0      Gesture1
# 1      Gesture1
# 2      Gesture1
# 3      Gesture1
# 4      Gesture1
# ...         ...
# 1576   Gesture4
# 1577   Gesture4
# 1578   Gesture4
# 1579   Gesture4
# 1580   Gesture4
#
# [1581 rows x 64 columns]

# %%
from sklearn.model_selection import train_test_split

X=data.iloc[:,:-1].values
Y=data.iloc[:,-1].values

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X.shape
# Out:
# (1581, 63)

# %%
Y.shape
# Out:
# (1581,)

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier=KNeighborsClassifier(n_neighbors=5)

classifier.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(Y_test,classifier.predict(X_test)))
# Out:
# 0.9968454258675079

# %%
import pickle

f=open('model.pkl','wb')
pickle.dump(classifier,f)
f.close()
